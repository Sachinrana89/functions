# %% [markdown]
# Exception Handling
# Exception handling in Python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. This lesson will cover the basics of exceptions, inclduding how to use try, except, else, finally blocks.
#
# What are Exceptions?
#
# Exceptions are events that disrupt the normal flow of program. They occur when an error is encountered during program execution. Common exceptions include:
#
# > zeroDivisionError: Dividing by zero
# > FileNotFoundError: File not found.
# > ValueError: Invalid value.
# > TypeError: Invalid type.

# %%
# exception try, except block

try:
    a=b
except:
    print("the variable has not been assigned yet")
# Out:
# the variable has not been assigned yet

# %%
try:
    a=b
except NameError as ex:
    print("the variable has not been assigned yet")
    print(ex)
# Out:
# the variable has not been assigned yet
# name 'b' is not defined

# %%
try:
    10/0
except ZeroDivisionError as ex:
    print(f"the error is {ex}")
# Out:
# the error is division by zero

# %%
try:
    result=1/2
    a=n
except ZeroDivisionError as ex:
    print(ex)
    print("please enter the denominator greater than 0")
except Exception as ex1:
    print(ex1)
    print("main exception get caught here")
# Out:
# name 'n' is not defined
# main exception get caught here

# %%
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError as ex:
    print(f"this is not a valid number {ex}")
except ZeroDivisionError as ex:
    print(f"enter denominator greater than 0 {ex}")
except Exception as ex:
    print(ex)
# Out:
# this is not a valid number invalid literal for int() with base 10: ''

# %%
# try, except, else, block
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError as ex:
    print(f"this is not a valid number {ex}")
except ZeroDivisionError as ex:
    print(f"enter denominator greater than 0 {ex}")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
# Out:
# the result is 0.22727272727272727

# %%
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError as ex:
    print(f"this is not a valid number {ex}")
except ZeroDivisionError as ex:
    print(f"enter denominator greater than 0 {ex}")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    print("execution complete")
# Out:
# this is not a valid number invalid literal for int() with base 10: 'd'
# execution complete

# %%
try:
    people=[
    {"name":"sachin","age":24},
    {"name":"anjali1","age":22},
    {"name":"rohit","age":12},
    {"name":"virat","age":19}
    ]
    def age_greater_than_18(person):
        return person["age"]>18
        rst=list(filter(age_greater_than_18, people))
        print(rst)
except Exception as ex:
    print(f"the error is {ex}")
# else:
#     print(f"the result is {rst}")
finally:
    print("execution done successfully")
# Out:
# execution done successfully

# %%
# file handling and exception handling
try:
    file=open('example.txt','r')
    content=file.read()
    print(content)

except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.close():
        file.close()
        print('file closed')
# Out:
# [Errno 2] No such file or directory: 'example.txt'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       8     print(ex)
#      10 finally:
# ---> 11     if 'file' in locals() or not file.close():
#      12         file.close()
#      13         print('file closed')
#
# NameError: name 'file' is not defined
